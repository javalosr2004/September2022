# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

x, y = np.array([25000, 48000, 56000, 64000]), np.array([1, 2, 3, 4])

plt.title('Minimum Wage In America')


plt.plot(x, y)
