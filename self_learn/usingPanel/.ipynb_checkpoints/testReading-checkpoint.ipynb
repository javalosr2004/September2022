# %%
import pandas as pd
import panel as pn
import numpy as np
pn.extension('tabulator')
import hvplot.pandas

# %%
df = pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv')
# Out:
#            country  year  ... trade_co2  trade_co2_share
# 0      Afghanistan  1949  ...       NaN              NaN
# 1      Afghanistan  1950  ...       NaN              NaN
# 2      Afghanistan  1951  ...       NaN              NaN
# 3      Afghanistan  1952  ...       NaN              NaN
# 4      Afghanistan  1953  ...       NaN              NaN
# ...            ...   ...  ...       ...              ...
# 26003     Zimbabwe  2016  ...     1.415            13.18
# 26004     Zimbabwe  2017  ...     1.666            17.39
# 26005     Zimbabwe  2018  ...     1.308            11.04
# 26006     Zimbabwe  2019  ...     1.473            13.45
# 26007     Zimbabwe  2020  ...       NaN              NaN
#
# [26008 rows x 60 columns]

# %%
df[df['year'] == 2019]
# Out:
#                  country  year  ... trade_co2  trade_co2_share
# 70           Afghanistan  2019  ...       NaN              NaN
# 207               Africa  2019  ...  -373.726           -26.53
# 295              Albania  2019  ...     0.988            20.31
# 400              Algeria  2019  ...       NaN              NaN
# 431              Andorra  2019  ...       NaN              NaN
# ...                  ...   ...  ...       ...              ...
# 25475  Wallis and Futuna  2019  ...       NaN              NaN
# 25746              World  2019  ...     0.000             0.00
# 25817              Yemen  2019  ...       NaN              NaN
# 25888             Zambia  2019  ...     2.971            42.15
# 26006           Zimbabwe  2019  ...     1.473            13.45
#
# [247 rows x 60 columns]

# %% [markdown]
# # Minor data processing:

# %%
df.fillna(0)
df['gdp_capita'] = np.where(df['population'] != 0, df['gdp']/df['population'], 0)

# %%
idf = df.interactive()

# %%
year_slider = pn.widgets.IntSlider(name = 'Year slider', start = 1750, end = 2020, step = 5, value = 1850)
year_slider
# Out:
# IntSlider(end=2020, name='Year slider', start=1750, step=5, value=1850)
